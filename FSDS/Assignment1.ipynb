# %%
import calendar

yr = int(
  input("Enter the year for which you want to find the leap year")
)
result = calendar.isleap(yr)
print(
  f"The given year {yr} is {'leap year' if result else 'not a leap year'}"
)

# %%
"""
Q1.Write a python program to find whether a given year is a leap year or not.
Test Data : 2016
Expected Output :
"""
import calendar

yr = int(
  input("Enter the year for which you want to find the leap year")
)
result = calendar.isleap(yr)
print(
  f"The given year {yr} is {'leap year' if result else 'not a leap year'}"
)

# %%
"""
Q2. Write a python program to read the value of an integer m and display the
value of n is 1 when m is larger than 0, 0 when m is 0 and -1 when m is less
than 0.
"""
m = int(input("Enter the value of m: "))
n = 1 if m>0 else 0 if m==0 else -1
print(f"The value of n is {n} for given m: {m}")

# %%
"""
Q3. Write a python program to accept a coordinate point in an XY coordinate
system and determine in which quadrant the coordinate point lies.
Test Data : 7 9
Expected Output :
The coordinate point (7,9) lies in the First quadrant.
"""
input_coordinates = (input("Enter the x coordinate and y coordinate (ex: 2 3) : "))
x, y = (int(coord) for coord in input_coordinates.strip().split(" "))

if x > 0 and y > 0:
    coordinate = "First quadrant"
elif x < 0 and y > 0:
    coordinate = "Second quadrant"
elif x < 0 and y < 0:
    coordinate = "Third quadrant"
elif x > 0 and y < 0:
    coordinate = "Fourth quadrant"
elif x==0 and y==0:
    coordinate = "On the origin"
else:
    coordinate = "On an axis"

print(
    f"The coordinate point ({x},{y}) lies in the {coordinate}."
)

# %%
"""
Q4. Write a python program to determine eligibility for admission to a
professional course based on the following criteria:
Eligibility Criteria : Marks in Maths &gt;=65 and Marks in Phy &gt;=55 and Marks in
Chem&gt;=50 and Total in all three subject &gt;=190 or Total in Maths and Physics
&gt;=140 ------------------------------------- Input the marks obtained in Physics :65
Input the marks obtained in Chemistry :51 Input the marks obtained in
Mathematics :72 Total marks of Maths, Physics and Chemistry : 188 Total
marks of Maths and Physics : 137 The candidate is not eligible.
Expected Output :
The candidate is not eligible for admission.
"""
math_marks=float(input("Enter the marks in maths: "))
phy_marks=float(input("Enter the marks in physics: "))
chem_marks=float(input("Enter the marks in chemistry: "))
total_marks=math_marks+phy_marks+chem_marks
total_math_phy=math_marks+phy_marks
if(math_marks>=65 and phy_marks>=55 and chem_marks>=50 and total_marks>=190) or total_math_phy>=140:
    print("The candidate is eligible for admission.")
else:
    print("The candidate is not eligible for admission.")

# %%
"""
Q6. Write a python program to read temperature in centigrade and display a
suitable message according to the temperature state below:
Temp < 0 then Freezing weather
Temp 0-10 then Very Cold weather
Temp 10-20 then Cold weather
Temp 20-30 then Normal in Temp
Temp 30-40 then Its Hot
Temp >=40 then Its Very Hot
Test Data :
42
Expected Output :
Its very hot.
"""
temp = int(input("Enter the temperature in centigrade: "))
if temp < 0:
    print("Freezing weather")
elif temp >= 0 and temp < 10:
    print("Very Cold weather")
elif temp >= 10 and temp < 20:
    print("Cold weather")
elif temp >= 20 and temp < 30:
    print("Normal in Temp")
elif temp >= 30 and temp < 40:
    print("Its Hot")
elif temp >= 40:
    print("Its very hot")

# %%
"""
Q7. Write a Python program to check whether a triangle is Equilateral,
Isosceles or Scalene.
Test Data :
50 50 60
Expected Output :
This is an isosceles triangle.
"""
# user_input=input("Enter the length of three sides of triangle: (ex: 50 50 60)")
user_input = "50 50 60"

side1,side2,side3 = (float(side) for side in user_input.split(" "))
if side1 == side2 == side3:
    print("This is an equilateral triangle.")
elif side1 == side2 or side1 == side3 or side2 == side3:
    print("This is an isosceles triangle.")
else:
    print("This is a scalene triangle.")

# %%
"""
Q8. Write a python program to check whether a triangle can be formed with
the given values for the angles.
Test Data :
40 55 65
Expected Output :
The triangle is not valid.
"""
sides = input("Enter the length of three sides of triangle: (ex: 50 50 60)")
side1,side2,side3 = (float(side) for side in sides.split(" "))
if side1+side2+side3 == 180:
    print("The triangle is valid.")
else:
    print("The triangle is not valid.")

# %%
"""Q9. Write a python program to check whether an alphabet is a vowel or a
consonant.
Test Data :
k
Expected Output :
The alphabet is a consonant.
"""
user_input=input("Enter the alphabet: ")
if user_input.lenth()>1:
    print("Please enter only one alphabet.")
if user_input.lower() in ['a','e','i','o','u']:
    print("The alphabet is a vowel.")
else:
    print("The alphabet is a consonant.")

# %%
"""
Q10. Write a Python program to calculate profit and loss on a transaction.
Test Data :
500 700
Expected Output :
You can booked your profit amount : 200
"""
prices = input("Enter the buy price and sell price: (ex: 500 700)")
buy_price,sell_price = (float(price) for price in prices.split(" "))
profit= sell_price-buy_price
if profit<0:
    print(f"You have incurred a loss of: {profit}")
else:
    print(f"You have booked a profit of: {profit}")

# %%
"""
Q11. Write a program in python to calculate and print the electricity bill of a
given customer. The customer ID, name, and unit consumed by the user
should be captured from the keyboard to display the total amount to be paid
to the customer.
The charge are as follow :
Unit Charge/unit
upto 199 @1.20
200 and above but less than 400 @1.50
400 and above but less than 600 @1.80
600 and above @2.00

If bill exceeds Rs. 400 then a surcharge of 15% will be charged and the
minimum bill should be of Rs. 100/-
"""
customer_id = input("Enter the customer ID: ")
customer_name = input("Enter the customer name: ")
units_consumed = float(input("Enter the units consumed: "))
if units_consumed <= 199:
    charge_per_unit = 1.20
elif units_consumed <= 399:
    charge_per_unit = 1.50
elif units_consumed <= 599
    charge_per_unit = 1.80
else:
    charge_per_unit = 2.00
total_bill = units_consumed * charge_per_unit
if total_bill > 400:
    total_bill += total_bill * 0.15
if total_bill < 100:
    total_bill = 100
print(f" For customer {customer_name} with id: {customer_id} the total bill is: {total_bill})

# %%
"""
Q12. Write a program in python to accept a grade and declare the equivalent
desription :
Grade Description
E Excellent
V Very Good
G Good
A Average
F Fail

Test Data :
Input the grade :A
Expected Output :
You have chosen : Average
"""
grade= input("Enter the grade: ").upper()
if grade == 'E':
    result = "Excellent"
elif grade == 'V':
    result = "Very Good"
elif grade == 'G':
    result = "Good"
elif grade == 'A':
    result = "Average"
elif grade == 'F':
    result = "Fail"
else:
    result = "Invalid grade"


print(f"You have chosen {grade}")

# %%
"""
Q13. Given two coordinates of a line starting is (x1,y1) and ending is (x2,y2)
find out the mid-point of a line.
"""
set1=input("Enter the (x1,y1) coordinates: ")
set2=input("Enter the (x2,y2) coordinates: ")
x1,y1 = (float(coordinate) for coordinate in set1.split(","))
x2,y2 = (float(coordinate) for coordinate in set2.split(","))
mid_x = (x1+x2)/2
mid_y = (y1+y2)/2
print(f"The mid-point of the line is: ({mid_x},{mid_y})")

# %%
"""
Q15. Given the dimensions of a rectangle (length and breadth), write a
program to determine whether the given rectangle is a square or not.
"""
user_input = input("Enter the length and breadth of the rectangle: ")
length, breadth = (float(side) for side in user_input.split(" "))
if length<=0 or breadth<=0:
    print("Invalid input. Please enter the valid input")
if length == breadth:
    print("The rectangle is a square.")
else:
    print("The rectangle is not a square.")

# %%
"""
Q16. Given three Cartesian coordinates, the task is to check if a right-angled
triangle can be formed by the given coordinates. If it is possible to create
a right-angled triangle, print Yes. Otherwise, print No.
Examples: 
Input: X1=0, Y1=5, X2=19, Y2=5, X3=0, Y3=0 
Output: Yes 
Explanation: 
Length of side connecting points (X1, Y1) and (X2, Y2) is 12. 
Length of side connecting points (X2, Y2) and (X3, Y3) is 15. 
Length of side connecting points (X1, Y1) and (X3, Y3) is 9. 
12 2 + 9 2 = 15 2 . 
Therefore, a right-angled triangle can be made.
Input: X1=5, Y1=14, X2=6, Y2=13, X3=8, Y3=7 
Output: No
"""
user_input1= input("enter the coordinates of the first point example x1 y1 : ")
user_input2= input("enter the coordinates of the second point example x2 y2 :")
user_input3= input("enter the coordinates of the third point example x3 y3 :")
x1,y1 = (float(coordinate) for coordinate in user_input1.split(" "))
x2,y2 = (float(coordinate) for coordinate in user_input2.split(" "))
x3,y3 = (float(coordinate) for coordinate in user_input3.split(" "))
length1 = ((x2-x1)**2 + (y2-y1)**2)**0.5
length2 = ((x3-x2)**2 + (y3-y2)**2)**0.5
length3 = ((x3-x1)**2 + (y3-y1)**2)**0.5
if ((length1**2 + length2**2) == length3**2) or ((length1**2 + length3**2) == length2**2) or ((length2**2 + length3**2) == length1**2):
    print("Yes")
else:
    print("No")
